# %%
#  Extraction of digits 

n = int(input("Enter a number: ") )
digit = 0
while n>0:
    digit = n % 10
    print(digit)
    n = n // 10

# %%
# check plaindrom in digits

n = int(input("Enter a number: ") )
num = n
result =0
while n>0:
  result = n%10 + result*10
  n = n // 10

if num == result:
    print("Palindrome")
else:
    print("Not a palindrome")

# %%
# count number of digits 
#  count number of digits 

n = int(input("Enter a number: ") )
count =0
while n>0:
   
    n = n // 10
    count=count+1
print("Number of digits: ",count)

# %%
#Armstreom number 


n= int(input("Enter a number: ")  )
num =n 

count =0 
while n>0:
    n = n // 10
    count = count +1
    
while num>0:
    digit = num % 10
    sum = sum + digit ** count
    num = num // 10

# %%
# additon of fisrt abd last digit in  A LIST 

arr =[1,2,3,4,5,6]

def add():
    first = arr[0]
    last = arr[-1]
    return first + last
