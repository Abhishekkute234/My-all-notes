# %%
# sum and product of all elements in an array 

L= [1,2,4,5,6,6]
summ =0 
product = 1

for i in L:
    summ = summ +i
print(summ)

for i in L:
    product = product *i
print(product)
# Out:
# 24
# 1440

# %%
#  Linear search 
L= [1,2,4,5,6,7]
index =0 
target= 5
for i in L :
    if i == target:
        print(i)
# Out:
# 5
