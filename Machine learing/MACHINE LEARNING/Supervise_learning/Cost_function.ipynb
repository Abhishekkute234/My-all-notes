# %% [markdown]
# # ->  Cost functions helps us to find the best fit line
# ## Keep the error minimum
#
# # ->Cost function works on overall dataset
# # -> Loss function works on only one row
#
# ![image.png](attachment:6863fe1e-cef6-4161-84d3-34ebb8670b24.png)
# ![image.png](attachment:9ea885a3-e90f-4274-9ec8-964530cee2ca.png)
# ![image.png](attachment:a8aa1110-170a-4990-9eb3-d25219f71b37.png)

# %% [markdown]
# # 1.REGRESSION COST FUNCTION

# %% [markdown]
# ![image.png](attachment:f9a40a21-551e-4075-aea2-336626885c74.png)
# # The Error should be minimum when the line paasse
# ![image.png](attachment:2b9031da-071c-4e7e-bbbf-533c9b41daea.png)
