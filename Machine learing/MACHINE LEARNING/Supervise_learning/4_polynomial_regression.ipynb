# %% [markdown]
# ![image.png](attachment:49416a0f-62e9-480d-bbee-9d1af268f193.png)
# ![image.png](attachment:4598d1d8-6c9e-4a5e-80a3-960821731922.png)

# %%
import pandas as pd
dataset= pd.read_csv("polynomial_regression_dataset.csv")
dataset.head(10)
# Out:
#    Level  Salary
# 0      1   -3636
# 1      2   27667
# 2      3   39873
# 3      4   84915
# 4      5  134947
# 5      6  171693
# 6      7  251716
# 7      8  326278
# 8      9  413290
# 9     10  503443

# %%
import matplotlib.pyplot as plt 
plt.scatter(dataset["Level"],dataset["Salary"])
plt.show()

# %%
dataset.corr()
# Out:
#           Level   Salary
# Level   1.00000  0.96885
# Salary  0.96885  1.00000

# %%
x= dataset[["Level"]]
y= dataset["Salary"]

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree =2)
pf.fit(x)
x= pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x, y , test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)* 100
# Out:
# 99.99998252085115

# %%
prd= lr.predict(x)

# %%
# prediction line 
mport matplotlib.pyplot as plt 
plt.plot(dataset["Level"], prd, c='red')
plt.scatter(dataset["Level"],dataset["Salary"])
plt.show()

# %%
test = pf.transform([[45]])
test
# Out:
# /home/abhishek/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[1.000e+00, 4.500e+01, 2.025e+03]])

# %%
lr.predict(test)
# Out:
# array([10125684.79997215])
