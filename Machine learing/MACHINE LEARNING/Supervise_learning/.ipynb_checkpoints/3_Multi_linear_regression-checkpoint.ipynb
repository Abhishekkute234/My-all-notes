# %% [markdown]
# # Multilinear regression

# %% [markdown]
# ## check the relation X1 , X2 , X3 ....and if the graph folow the linearity then we use multi linear regression
#
# # Equation is
# ## Y = m1x1 +m2x2 +m3x3 ... + c

# %%
import pandas as pd 
dataset= pd.read_csv("multi_linear_regression_dataset.csv")
dataset.head(10)
# Out:
#    Age  Experience (Years)         Salary
# 0   50                  32  100791.169884
# 1   36                  16   68779.174574
# 2   29                   7   56985.080365
# 3   42                  18   69267.605576
# 4   40                  17   75190.113294
# 5   44                  24   96672.855985
# 6   32                  14   73225.173820
# 7   32                  10   47700.443907
# 8   45                  26   86686.865179
# 9   57                  33  110243.296936

# %%
dataset.shape
dataset.isnull().sum()
# Out:
# Age                   0
# Experience (Years)    0
# Salary                0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(data=dataset)
plt.show()

# %%
x= dataset.iloc[:-1]
x
# Out:
#     Age  Experience (Years)         Salary
# 0    50                  32  100791.169884
# 1    36                  16   68779.174574
# 2    29                   7   56985.080365
# 3    42                  18   69267.605576
# 4    40                  17   75190.113294
# ..  ...                 ...            ...
# 94   45                  24   90675.562755
# 95   58                  35  107698.995650
# 96   56                  32  100671.512230
# 97   43                  24   82346.190785
# 98   48                  28   90472.500651
#
# [99 rows x 3 columns]

# %%
# to see the Colinearity of the graph\
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %%
# Define features (independent variables) and target (dependent variable)
x = dataset[['Age', 'Experience (Years)']]  # Features
y = dataset['Salary']  # Target

# %%
# Train test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=52)

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9492308123555192

# %%
lr.coef_
# Out:
# array([ 277.36896996, 1855.33541581])

# %%
lr.intercept_
# Out:
# np.float64(30296.706308802386)

# %%
lr.predict(x_test)
# Out:
# array([114476.77901177,  91017.03076825,  69689.9869105 , 106500.6994086 ,
#         51327.75434842,  52905.72079427,  89716.43329236,  58749.09601166,
#         93427.10412399,  84618.91761092,  72932.16717613, 110211.37024022,
#        110766.10818015, 101403.18372716,  92872.36618406,  85173.65555085,
#         58003.23647571, 100934.69316116,  55038.42518004,  92872.36618406])
